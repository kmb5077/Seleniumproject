# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import math

rawdf = pd.read_csv("apts2.csv",header=None)
rawdf.columns = ['Address', 'Neighborhood','Price','Apt Type','Bedrooms','Bathrooms','Rooms','Sqft','Description']

# %%
rawdf
# Out:
#                      Address          Neighborhood         Price     Apt Type  \
# 0          421 Broome Street           Soho/Nolita  $65,000,000         Condo
# 1        53 West 53rd Street          Midtown West  $63,815,000         Condo
# 2             100 BARCLAY ST               Tribeca  $59,000,000         Condo
# 3        53 West 53rd Street          Midtown West  $46,395,000         Condo
# 4           1908 Park Avenue           East Harlem  $40,000,000    Commercial
# 5         20 East End Avenue       Upper East Side  $39,500,000         Condo
# 6        11 East 82nd Street       Upper East Side  $39,000,000     Townhouse
# 7            7 SUTTON SQUARE           Sutton Area  $35,900,000     Townhouse
# 8     38-40 East 75th Street       Upper East Side  $33,800,000     Townhouse
# 9            15 Hudson Yards  Chelsea/Hudson Yards  $32,000,000         Condo
# 10             30 PARK PLACE               Tribeca  $30,000,000         Condo
# ...

# %%
rawdf.to_html('table.html')

# %%
rawdf.dtypes
# Out:
# Address          object
# Neighborhood     object
# Price            object
# Apt Type         object
# Bedrooms        float64
# Bathrooms       float64
# Rooms           float64
# Sqft             object
# Description      object
# dtype: object

# %%
rawdf.shape
# Out:
# (1317, 9)

# %%
np.sum(rawdf.isnull())
# Out:
# Address           0
# Neighborhood      0
# Price            23
# Apt Type          1
# Bedrooms        339
# Bathrooms       342
# Rooms            35
# Sqft            438
# Description       0
# dtype: int64

# %%
df1=rawdf.dropna(axis=0)

# %%
df2=rawdf.dropna(axis=0)

# %%
df1.shape
# Out:
# (690, 9)

# %%
df1
# Out:
#                     Address          Neighborhood         Price   Apt Type  \
# 0         421 Broome Street           Soho/Nolita  $65,000,000       Condo
# 1       53 West 53rd Street          Midtown West  $63,815,000       Condo
# 2            100 BARCLAY ST               Tribeca  $59,000,000       Condo
# 3       53 West 53rd Street          Midtown West  $46,395,000       Condo
# 5        20 East End Avenue       Upper East Side  $39,500,000       Condo
# 7           7 SUTTON SQUARE           Sutton Area  $35,900,000   Townhouse
# 9           15 Hudson Yards  Chelsea/Hudson Yards  $32,000,000       Condo
# 10            30 PARK PLACE               Tribeca  $30,000,000       Condo
# 11      10 East 76th Street       Upper East Side  $29,950,000   Townhouse
# 12            30 PARK PLACE               Tribeca  $29,500,000       Condo
# 13            56 LEONARD ST               Tribeca  $29,500,000       Condo
# ...

# %%
df1["Price"]=list(map(lambda x: x.replace(',',''.strip()),df1["Price"]))
df1["Price"]=list(map(lambda x: x.replace('$',''.strip()),df1["Price"]))
df1["Price"]=df1["Price"].astype('int')
df1["Sqft"]=list(map(lambda x: x.replace(',',''.strip()),df1["Sqft"]))
df1["Sqft"]=df1["Sqft"].astype('int')
df1["$/Sqft"]=df1["Price"]/df1['Sqft']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1
# Out:
#                     Address          Neighborhood     Price   Apt Type  \
# 0         421 Broome Street           Soho/Nolita  65000000      Condo
# 1       53 West 53rd Street          Midtown West  63815000      Condo
# 2            100 BARCLAY ST               Tribeca  59000000      Condo
# 3       53 West 53rd Street          Midtown West  46395000      Condo
# 5        20 East End Avenue       Upper East Side  39500000      Condo
# 7           7 SUTTON SQUARE           Sutton Area  35900000  Townhouse
# 9           15 Hudson Yards  Chelsea/Hudson Yards  32000000      Condo
# 10            30 PARK PLACE               Tribeca  30000000      Condo
# 11      10 East 76th Street       Upper East Side  29950000  Townhouse
# 12            30 PARK PLACE               Tribeca  29500000      Condo
# 13            56 LEONARD ST               Tribeca  29500000      Condo
# 14       3 East 89th Street         Carnegie Hill  27000000  Townhouse
# ...

# %%
df1.dtypes
# Out:
# Address          object
# Neighborhood     object
# Price             int64
# Apt Type         object
# Bedrooms        float64
# Bathrooms       float64
# Rooms           float64
# Sqft              int64
# Description      object
# $/Sqft          float64
# dtype: object

# %%
len(df1["Neighborhood"].unique())
# Out:
# 28

# %%
df1["Neighborhood"].unique()
# Out:
# array(['Soho/Nolita', 'Midtown West', 'Tribeca', 'Upper East Side',
#        'Sutton Area', 'Chelsea/Hudson Yards', 'Carnegie Hill',
#        'NoMad, USA', 'Central Park South', 'Upper West Side',
#        'West Village', 'Greenwich Village', 'Gramercy', 'Flatiron',
#        'Clinton', 'Midtown East', 'Battery Park City',
#        'Financial District', 'Lower East Side', 'Hamilton Heights',
#        'Murray Hill', 'Harlem', 'East Village', 'Beekman',
#        'Roosevelt Island', 'Morningside Heights', 'East Harlem', 'Inwood'],
#       dtype=object)

# %%
df1.describe()
# Out:
#               Price    Bedrooms   Bathrooms       Rooms          Sqft  \
# count  6.900000e+02  690.000000  690.000000  690.000000    690.000000
# mean   5.414923e+06    2.653623    2.789130    5.528986   2203.881159
# std    6.857999e+06    1.329697    1.476752    2.703253   1641.353337
# min    4.350000e+05    1.000000    1.000000    2.000000    500.000000
# 25%    1.814492e+06    2.000000    2.000000    4.000000   1201.250000
# 50%    3.300000e+06    2.000000    2.500000    5.000000   1703.000000
# 75%    5.690000e+06    3.000000    3.500000    6.000000   2590.500000
# max    6.500000e+07   12.000000   10.500000   25.000000  14539.000000
#
#             $/Sqft
# count   690.000000
# mean   2120.853043
# std    1081.420457
# min     576.666667
# 25%    1410.296955
# 50%    1891.963682
# 75%    2603.768370
# max    8125.000000

# %%
df1['Price'].sum()/df1['Sqft'].sum()
# Out:
# 2456.9939645342406

# %%
grouphood=df1.groupby("Neighborhood")
for apt in grouphood:
    print (apt)
# Out:
# ('Battery Park City',                     Address       Neighborhood     Price Apt Type  Bedrooms  \
# 103          10 West Street  Battery Park City  10499000    Condo       4.0
# 153   70 Little West Street  Battery Park City   7495000    Condo       4.0
# 280          10 West Street  Battery Park City   4800000    Condo       3.0
# 348          30 West Street  Battery Park City   3995000    Condo       4.0
# 521          10 West Street  Battery Park City   2845000    Condo       2.0
# 569          10 West Street  Battery Park City   2600000    Condo       2.0
# 627          30 West Street  Battery Park City   2250000    Condo       2.0
# 637   70 Little West Street  Battery Park City   2199000    Condo       2.0
# 657           212 WARREN ST  Battery Park City   2095000    Condo       2.0
# 968        333 RECTOR PLACE  Battery Park City    995000    Condo       1.0
# 989        380 RECTOR PLACE  Battery Park City    950000    Condo       1.0
# ...

# %%
for hood, apt in grouphood:
    print(hood) #this indicates the grouping
    print('-'*70)
    print(apt) #this is a dataframe for that 
    print('\n')
# Out:
# Battery Park City
# ----------------------------------------------------------------------
#                     Address       Neighborhood     Price Apt Type  Bedrooms  \
# 103          10 West Street  Battery Park City  10499000    Condo       4.0
# 153   70 Little West Street  Battery Park City   7495000    Condo       4.0
# 280          10 West Street  Battery Park City   4800000    Condo       3.0
# 348          30 West Street  Battery Park City   3995000    Condo       4.0
# 521          10 West Street  Battery Park City   2845000    Condo       2.0
# 569          10 West Street  Battery Park City   2600000    Condo       2.0
# 627          30 West Street  Battery Park City   2250000    Condo       2.0
# 637   70 Little West Street  Battery Park City   2199000    Condo       2.0
# 657           212 WARREN ST  Battery Park City   2095000    Condo       2.0
# 968        333 RECTOR PLACE  Battery Park City    995000    Condo       1.0
# ...

# %%
grouphood.size()
# Out:
# Neighborhood
# Battery Park City        12
# Beekman                   1
# Carnegie Hill            18
# Central Park South       10
# Chelsea/Hudson Yards     44
# Clinton                   9
# East Harlem               2
# East Village              5
# Financial District       26
# Flatiron                 13
# Gramercy                 28
# Greenwich Village        26
# Hamilton Heights          7
# Harlem                   19
# Inwood                    1
# Lower East Side          11
# Midtown East             29
# Midtown West             34
# Morningside Heights       1
# Murray Hill              15
# NoMad, USA               17
# Roosevelt Island         12
# Soho/Nolita              22
# Sutton Area              13
# Tribeca                  73
# Upper East Side         123
# Upper West Side         112
# West Village              7
# dtype: int64

# %%
manhood=grouphood.mean()

# %%
manhood.sort_values('Price',ascending=False).head(10)
# Out:
#                              Price  Bedrooms  Bathrooms     Rooms  \
# Neighborhood
# Central Park South    1.229750e+07  3.100000   3.550000  6.600000
# Midtown West          9.721147e+06  2.529412   2.808824  5.073529
# Soho/Nolita           8.741136e+06  2.681818   2.863636  5.931818
# Tribeca               8.229445e+06  3.041096   3.232877  5.746575
# Carnegie Hill         7.730278e+06  3.333333   3.388889  6.972222
# West Village          6.953571e+06  2.571429   3.357143  7.214286
# Chelsea/Hudson Yards  6.465773e+06  2.727273   2.920455  5.011364
# NoMad, USA            6.059647e+06  2.529412   2.705882  5.029412
# Greenwich Village     5.760346e+06  2.769231   3.115385  6.211538
# Upper East Side       5.233313e+06  2.617886   2.817073  5.646341
#
#                              Sqft       $/Sqft
# Neighborhood
# Central Park South    2608.000000  4318.053874
# Midtown West          2536.088235  3006.902087
# Soho/Nolita           3037.045455  2232.291946
# ...

# %%
grouphoodtype=df1.groupby(['Neighborhood','Apt Type'])
grouphoodbedrooms=df1.groupby(['Neighborhood','Bedrooms'])

# %%
grouphoodtype.size()
# Out:
# Neighborhood          Apt Type
# Battery Park City     Condo          12
# Beekman               Condo           1
# Carnegie Hill         Co-op           8
#                       Condo           9
#                       Townhouse       1
# Central Park South    Co-op           1
#                       Condo           9
# Chelsea/Hudson Yards  Co-op           3
#                       Condo          41
# Clinton               Condo           8
#                       Townhouse       1
# East Harlem           Condo           2
# East Village          Co-op           1
#                       Condo           4
# Financial District    Condo          26
# Flatiron              Co-op           4
#                       Condo           9
# Gramercy              Co-op           4
#                       Condo          23
#                       Townhouse       1
# Greenwich Village     Co-op          10
#                       Condo          10
#                       Condo/Co-op     1
# ...

# %%
grouphoodbedrooms.size()
# Out:
# Neighborhood          Bedrooms
# Battery Park City     1.0          2
#                       2.0          6
#                       3.0          1
#                       4.0          3
# Beekman               3.0          1
# Carnegie Hill         1.0          1
#                       2.0          5
#                       3.0          4
#                       4.0          5
#                       5.0          2
#                       7.0          1
# Central Park South    1.0          1
#                       2.0          3
#                       3.0          3
#                       4.0          1
#                       5.0          1
#                       6.0          1
# Chelsea/Hudson Yards  1.0          3
#                       2.0         16
#                       3.0         16
#                       4.0          8
#                       5.0          1
# Clinton               1.0          2
#                       2.0          4
# ...

# %%
grouphoodbedrooms.agg(['count', 'sum', 'min', 'max', 'mean', 'std'])
# Out:
#                               Price                                 \
#                               count        sum       min       max
# Neighborhood         Bedrooms
# Battery Park City    1.0          2    1945000    950000    995000
#                      2.0          6   12838000    849000   2845000
#                      3.0          1    4800000   4800000   4800000
#                      4.0          3   21989000   3995000  10499000
# Beekman              3.0          1    2849000   2849000   2849000
# Carnegie Hill        1.0          1     875000    875000    875000
#                      2.0          5   17525000   1350000   4950000
#                      3.0          4   25050000   2450000  13450000
#                      4.0          5   44695000   3795000  12900000
#                      5.0          2   24000000   5500000  18500000
#                      7.0          1   27000000  27000000  27000000
# ...

# %%
grouphoodtype.agg(['count', 'sum', 'min', 'max', 'mean', 'std'])
# Out:
#                                  Price                                 \
#                                  count        sum       min       max
# Neighborhood         Apt Type
# Battery Park City    Condo          12   41572000    849000  10499000
# Beekman              Condo           1    2849000   2849000   2849000
# Carnegie Hill        Co-op           8   49570000    875000  18500000
#                      Condo           9   62575000   3250000  12900000
#                      Townhouse       1   27000000  27000000  27000000
# Central Park South   Co-op           1    2950000   2950000   2950000
#                      Condo           9  120025000   3275000  23850000
# Chelsea/Hudson Yards Co-op           3    4864000    619000   2850000
#                      Condo          41  279630000   1800000  32000000
# Clinton              Condo           8   22482000    958000   8995000
#                      Townhouse       1   10995000  10995000  10995000
# ...

# %%
grouphood.agg(['count', 'sum', 'min', 'max', 'mean', 'std'])
# Out:
#                      Price                                              \
#                      count        sum      min       max          mean
# Neighborhood
# Battery Park City       12   41572000   849000  10499000  3.464333e+06
# Beekman                  1    2849000  2849000   2849000  2.849000e+06
# Carnegie Hill           18  139145000   875000  27000000  7.730278e+06
# Central Park South      10  122975000  2950000  23850000  1.229750e+07
# Chelsea/Hudson Yards    44  284494000   619000  32000000  6.465773e+06
# Clinton                  9   33477000   958000  10995000  3.719667e+06
# East Harlem              2    1925000   635000   1290000  9.625000e+05
# East Village             5   10838000  1350000   3595000  2.167600e+06
# Financial District      26   70478965   889000   9925000  2.710729e+06
# Flatiron                13   58272000   849000  12000000  4.482462e+06
# Gramercy                28  102102000   550000  17800000  3.646500e+06
# ...

# %%
Tribeca=df1[df1.Neighborhood == "Tribeca"]
Tribeca['Log_Price']=Tribeca['Price'].apply(math.log)
WV=df1[df1.Neighborhood == "West Village"]
WV['Log_Price']=WV['Price'].apply(math.log)
EV=df1[df1.Neighborhood == "East Village"]
EV['Log_Price']=EV['Price'].apply(math.log)
UES=df1[df1.Neighborhood == "Upper East Side"]
UES['Log_Price']=UES['Price'].apply(math.log)
UWS=df1[df1.Neighborhood == "Upper West Side"]
UWS['Log_Price']=UWS['Price'].apply(math.log)
Midtownwest=df1[df1.Neighborhood == "Midtown West"]
Midtownwest['Log_Price']=Midtownwest['Price'].apply(math.log)
Soho=df1[df1.Neighborhood == "Soho/Nolita"]
Soho['Log_Price']=Soho['Price'].apply(math.log)
Chelsea=df1[df1.Neighborhood == "Chelsea/Hudson Yards"]
Chelsea['Log_Price']=Chelsea['Price'].apply(math.log)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
Tribecaboxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=Tribeca)

# %%
WVboxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=WV)

# %%
EVboxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=EV)

# %%
Sohoboxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=Soho)

# %%
UWSboxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=UWS)

# %%
UESboxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=UES)

# %%
df2
# Out:
#                     Address          Neighborhood         Price   Apt Type  \
# 0         421 Broome Street           Soho/Nolita  $65,000,000       Condo
# 1       53 West 53rd Street          Midtown West  $63,815,000       Condo
# 2            100 BARCLAY ST               Tribeca  $59,000,000       Condo
# 3       53 West 53rd Street          Midtown West  $46,395,000       Condo
# 5        20 East End Avenue       Upper East Side  $39,500,000       Condo
# 7           7 SUTTON SQUARE           Sutton Area  $35,900,000   Townhouse
# 9           15 Hudson Yards  Chelsea/Hudson Yards  $32,000,000       Condo
# 10            30 PARK PLACE               Tribeca  $30,000,000       Condo
# 11      10 East 76th Street       Upper East Side  $29,950,000   Townhouse
# 12            30 PARK PLACE               Tribeca  $29,500,000       Condo
# 13            56 LEONARD ST               Tribeca  $29,500,000       Condo
# ...

# %%
df2["Price"]=list(map(lambda x: x.replace(',',''.strip()),df2["Price"]))
df2["Price"]=list(map(lambda x: x.replace('$',''.strip()),df2["Price"]))
df2["Price"]=df2["Price"].astype('int')
df2["Sqft"]=list(map(lambda x: x.replace(',',''.strip()),df2["Sqft"]))
df2["Sqft"]=df2["Sqft"].astype('int')
df2["$/Sqft"]=df2["Price"]/df2['Sqft']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2['Log_Price']=df2['Price'].apply(math.log)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2boxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=df2,width=.8,)
plt.gcf().set_size_inches((15, 10))    
plt.show()

# %%
df2boxplot=sns.boxplot(x='Log_Price', y='Neighborhood', data=df2,)
plt.gcf().set_size_inches((15, 10))    
plt.show()
