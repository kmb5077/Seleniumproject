# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import math

rawdf = pd.read_csv("aptsBK.csv",header=None)
rawdf.columns = ['Address', 'Neighborhood','Price','Apt Type','Bedrooms','Bathrooms','Rooms','Sqft','Description']

# %%
rawdf
# Out:
#                        Address        Neighborhood         Price    Apt Type  \
# 0    203-209 North 11th Street        Williamsburg  $18,000,000   Commercial
# 1              8121 Shore Road           Bay Ridge  $15,000,000        House
# 2           532 Clinton Avenue        Clinton Hill   $9,760,000    Townhouse
# 3            143 Willow Street    Brooklyn Heights   $9,750,000    Townhouse
# 4       1101-110 Fulton Street        Clinton Hill   $7,920,000    Townhouse
# 5         76 Pierrepont Street    Brooklyn Heights   $6,950,000    Townhouse
# 6            130 Furman Street    Brooklyn Heights   $6,250,000        Condo
# 7            130 Furman Street    Brooklyn Heights   $5,750,000        Condo
# 8       672 Saint Marks Avenue       Crown Heights   $5,300,000    Townhouse
# 9             169 Hicks Street    Brooklyn Heights   $5,300,000    Townhouse
# 10            196 Hicks Street    Brooklyn Heights   $5,250,000        Co-op
# ...

# %%
df1=rawdf.dropna(axis=0)

# %%
df1.shape
# Out:
# (302, 9)

# %%
df1["Price"]=list(map(lambda x: x.replace(',',''.strip()),df1["Price"]))
df1["Price"]=list(map(lambda x: x.replace('$',''.strip()),df1["Price"]))
df1["Price"]=df1["Price"].astype('int')
df1["Sqft"]=list(map(lambda x: x.replace(',',''.strip()),df1["Sqft"]))
df1["Sqft"]=df1["Sqft"].astype('int')
df1["$/Sqft"]=df1["Price"]/df1['Sqft']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1
# Out:
#                     Address        Neighborhood     Price   Apt Type  \
# 1           8121 Shore Road           Bay Ridge  15000000      House
# 5      76 Pierrepont Street    Brooklyn Heights   6950000  Townhouse
# 6         130 Furman Street    Brooklyn Heights   6250000      Condo
# 7         130 Furman Street    Brooklyn Heights   5750000      Condo
# 8    672 Saint Marks Avenue       Crown Heights   5300000  Townhouse
# 9          169 Hicks Street    Brooklyn Heights   5300000  Townhouse
# 10         196 Hicks Street    Brooklyn Heights   5250000      Co-op
# 11         90 Furman Street    Brooklyn Heights   4950000      Condo
# 13     848 President Street          Park Slope   4750000  Townhouse
# 14      669 East 2nd Street          Kensington   4750000  Townhouse
# 17           815 5th Avenue           Greenwood   4550000  Townhouse
# 18         98 Degraw Street            Brooklyn   4500000  Townhouse
# 19         96 Degraw Street            Brooklyn   4500000  Townhouse
# ...

# %%
plt.scatter(np.log(df1['Price']),df1['Neighborhood'])
plt.gcf().set_size_inches((15, 8))    
plt.show()

# %%
df1_score = df1[['Neighborhood', 'Price']]
df1_score.boxplot(by='Neighborhood', column='Price')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.boxplot(x='Neighborhood', y='Price', data=df1)

# %%
df2=rawdf.dropna(axis=0)
df2["Price"]=list(map(lambda x: x.replace(',',''.strip()),df2["Price"]))
df2["Price"]=list(map(lambda x: x.replace('$',''.strip()),df2["Price"]))
df2["Price"]=df2["Price"].astype('int')
df2["Sqft"]=list(map(lambda x: x.replace(',',''.strip()),df2["Sqft"]))
df2["Sqft"]=df2["Sqft"].astype('int')
df2["$/Sqft"]=df2["Price"]/df2['Sqft']
df2['Log_Price']=df2['Price'].apply(math.log)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2boxplot=sns.boxplot(x='Bedrooms', y='Log_Price', data=df2,width=.8,)
plt.gcf().set_size_inches((15, 10))    
plt.show()

# %%
df2boxplot=sns.boxplot(x='Log_Price', y='Neighborhood', data=df2,)
plt.gcf().set_size_inches((15, 10))    
plt.show()
